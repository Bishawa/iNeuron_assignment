# %% [markdown]
# <a href="https://colab.research.google.com/github/Bishawa/iNeuron_assignment/blob/main/iNeuron_Python_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Q1) In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Q2) What is the difference between string and variable?

# %% [markdown]
# A string is a value enclosed in single, double or triple quote and whereas variables are created to store a value which can be string, integer, float, Boolean, list, set, etc. So we can say that variables are symbolic character used to store an object in python.

# %% [markdown]
# ### Q3) Describe three different data types.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Q4) What is an expression made up of? What do all expressions do?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Q5) This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Q6) After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [markdown]
# There won’t be any changes in bacon because we are not re-assigning the value. The value of bacon will remain 22

# %% [markdown]
# ### Q7) What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# ### Q8) Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# We can use alphabets, digits and underscore while naming a variable but a variable name can’t start with a digit.

# %% [markdown]
# ### Q9) What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = '45'
int(s) + 30
# Out:
# 75

# %%
type(float(s))
# Out:
# float

# %%
i = 45
str(i) + 'hello'
# Out:
# '45hello'

# %% [markdown]
# ### Q10) Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'I have eaten' + 99 + 'burritos'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-9230c793b9b6> in <cell line: 1>()
# ----> 1 'I have eaten' + 99 + 'burritos'
#
# TypeError: can only concatenate str (not "int") to str

# %%
'I have eaten' + ' 99 ' + 'burritos'
# Out:
# 'I have eaten 99 burritos'

# %%
'I have eaten' +' ' + str(99) + ' ' + 'burritos'
# Out:
# 'I have eaten 99 burritos'
