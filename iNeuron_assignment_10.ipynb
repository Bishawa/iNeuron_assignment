# %% [markdown]
# Q1. What is the role of try and exception block?
#
# ![image.png](attachment:image.png)

# %%
try:
    a = int(input("enter first number"))
    b = int(input("enter second number"))
    c = a/b
    print(c)
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'he'

# %% [markdown]
# Q2. What is the syntax for a basic try-except block?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Q3. What happens if an exception occurs inside a try block and there is no matching except block?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Q3. What happens if an exception occurs inside a try block and there is no matching except block?
# ![image.png](attachment:image.png)

# %% [markdown]
# Q4. What is the difference between using a bare except block and specifying a specific exception type?
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# Example for bare except block
try:
    x = 10 / 0
except:
    print("An error occurred")
# Out:
# An error occurred

# %%
# Example of specific exception type
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %% [markdown]
# Q5. Can you have nested try-except blocks in Python? If yes, then give an example.
# ![image.png](attachment:image.png)

# %%
# Example for nested try-except block
try:
    # Outer try block
    num = int(input("Enter a number: "))
    
    try:
        # Inner try block
        result = 10 / num
        print("Result:", result)
        
    except ZeroDivisionError:
        print("Inner except block: Division by zero is not allowed.")
    
except ValueError:
    print("Outer except block: Please enter a valid number.")
# Out:
# Enter a number: 45
# Result: 0.2222222222222222

# %% [markdown]
# Q6. Can we use multiple exception blocks, if yes then give an example.
# ![image.png](attachment:image.png)

# %%
# Example for multiple except block
try:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    result = num1 / num2
    print("Result:", result)

except ValueError:
    print("Invalid input. Please enter valid integers.")

except ZeroDivisionError:
    print("Division by zero is not allowed.")

except Exception as e:
    print("An error occurred:", e)
# Out:
# Enter the first number: 26
# Enter the second number: 35
# Result: 0.7428571428571429

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
# EOF error
try:
    data = input("Enter data: ")
    print("You entered:", data)
except EOFError:
    print("EOFError: End of file reached unexpectedly.")
# Out:
# Enter data: hello
# You entered: hello

# %%
# Floating Point Error
result = 1.0 / 0.0  # This will raise a FloatingPointError
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # FloatingPointError
# ----> 2 result = 1.0 / 0.0
#
# ZeroDivisionError: float division by zero

# %%
# Index Error
my_list = [1, 2, 3]
print(my_list[3])  # This will raise an IndexError because the index is out of range.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Index Error
#       2 my_list = [1, 2, 3]
# ----> 3 print(my_list[3])
#
# IndexError: list index out of range

# %%
# memmory error
# Attempting to allocate a large list may lead to a MemoryError.

a = [0] * 10**8

# %%
# overflow error
import math
# Factorial of 1000 is too large to be represented with Python's built-in integer type.
result = math.factorial(1000)

# %%
# Tab Error
if True:
# Mixing tabs and spaces will cause a TabError.
print("Indented with a tab.")
# Out:
#   Cell In[14], line 4
#     print("Indented with a tab.")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# value error
# Attempting to convert a non-integer string to an integer.

try:
    num = int("abc")  
except ValueError:
    print("ValueError: Invalid value for conversion.")
# Out:
# ValueError: Invalid value for conversion.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# program to divide two numbers
try:
    num1 = int(input('Enter a number'))
    num2 = int(input('Enter a number'))
    try:
        result = num1/num2
        print(result)
    except ZeroDivisionError:
        print("Division by zero is not allowed")
except ValueError:
    print("please enter a number")
# Out:
# Enter a number45
# Enter a numberkl
# please enter a number

# %%
# program to convert a string to an integer
try:
    a = input('Enter your string')
    num = int(a)
    print('the interger of the given number is', num)
except Exception as e:
    print('Please enter a valid string')
# Out:
# Enter your stringhj
# Please enter a valid string

# %%
# Program to access an element in the list
list1 = input('enter your list').split()
try:
    index = input('Enter the index you want to access')
    print(list1[int(index)])
except Exception as e:
    print(e)
# Out:
# enter your list45 96 85 62
# Enter the index you want to accesssd
# invalid literal for int() with base 10: 'sd'

# %%
# a program to handle a specific error
try:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    result = num1 / num2
    print("Result:", result)

except ValueError:
    print("Invalid input. Please enter valid integers.")

except ZeroDivisionError:
    print("Division by zero is not allowed.")

except Exception as e:
    print("An error occurred:", e)
# Out:
# Enter the first number: 53
# Enter the second number: kl
# Invalid input. Please enter valid integers.

# %%
# program to handle any error
try:
    a = input('Enter your string')
    num = int(a)
    print('the interger of the given number is', num)
except Exception as e:
    print('Please enter a valid string')
# Out:
# Enter your stringtg
# Please enter a valid string
